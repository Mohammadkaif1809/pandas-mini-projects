# %%
# dataFrame
#collection of series is called dataFrame

import numpy as np
import pandas as pd

# %%
data = {
  "name":["kaif","sadhik","ishu","sonu"],
  "gender":["m","m","f","m"],
  "age":[22,14,11,19],
  "study":["grad","school","school","college"] 
}

# %%
df = pd.DataFrame(data)

# %%
data2 = [
  ["kaif",22,"grad"],
  ["riyaz",19,"college"],
  ["munna",16,"diploma"]
]

# %%
pd.DataFrame(data2)
# Out:
#        0   1        2
# 0   kaif  22     grad
# 1  riyaz  19  college
# 2  munna  16  diploma

# %%
col = ["name","age","work"]

# %%
pd.DataFrame(data2,columns=col)
# Out:
#     name  age     work
# 0   kaif   22     grad
# 1  riyaz   19  college
# 2  munna   16  diploma

# %%
#adding col

df["place"] = ["hyd","wgl","wgl","pkpl"]

# %%
df
# Out:
#      name gender  age    study place
# 0    kaif      m   22     grad   hyd
# 1  sadhik      m   14   school   wgl
# 2    ishu      f   11   school   wgl
# 3    sonu      m   19  college  pkpl

# %%
df.drop(["study"],axis = 1)
# Out:
#      name gender  age place
# 0    kaif      m   22   hyd
# 1  sadhik      m   14   wgl
# 2    ishu      f   11   wgl
# 3    sonu      m   19  pkpl

# %%
df.drop(2,axis = 0)
# Out:
#      name gender  age    study place
# 0    kaif      m   22     grad   hyd
# 1  sadhik      m   14   school   wgl
# 3    sonu      m   19  college  pkpl

# %%
df
# Out:
#      name gender  age    study place
# 0    kaif      m   22     grad   hyd
# 1  sadhik      m   14   school   wgl
# 2    ishu      f   11   school   wgl
# 3    sonu      m   19  college  pkpl

# %%
df.drop("study",axis=1,inplace=True)

# %%
df
# Out:
#      name gender  age place
# 0    kaif      m   22   hyd
# 1  sadhik      m   14   wgl
# 2    ishu      f   11   wgl
# 3    sonu      m   19  pkpl

# %%
df["name"]
# Out:
# 0      kaif
# 1    sadhik
# 2      ishu
# 3      sonu
# Name: name, dtype: str

# %%
df[["name","age"]]
# Out:
#      name  age
# 0    kaif   22
# 1  sadhik   14
# 2    ishu   11
# 3    sonu   19

# %%
df.loc[[1,3]]
# Out:
#      name gender  age place
# 1  sadhik      m   14   wgl
# 3    sonu      m   19  pkpl

# %%
df
# Out:
#      name gender  age place
# 0    kaif      m   22   hyd
# 1  sadhik      m   14   wgl
# 2    ishu      f   11   wgl
# 3    sonu      m   19  pkpl

# %%
df.loc[[2,3]][["name","gender"]]
# Out:
#    name gender
# 2  ishu      f
# 3  sonu      m

# %%
#conditions

df[df["age"]<=20]
# Out:
#      name gender  age place
# 1  sadhik      m   14   wgl
# 2    ishu      f   11   wgl
# 3    sonu      m   19  pkpl

# %%
df[(df["age"]<=20) & (df["gender"]=="m")]
# Out:
#      name gender  age place
# 1  sadhik      m   14   wgl
# 3    sonu      m   19  pkpl
