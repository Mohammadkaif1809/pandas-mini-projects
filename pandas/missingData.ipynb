# %%
# missing data

import numpy as np
import pandas as pd

# %%
data = {
  "name":["kaif","aaryan","roxoy",pd.NA],
  "age":[pd.NA,27,25,18],
  "occupation":["data eng",pd.NA,pd.NA,pd.NA]
}

# %%
data
# Out:
# {'name': ['kaif', 'aaryan', 'roxoy', <NA>],
#  'age': [<NA>, 27, 25, 18],
#  'occupation': ['data eng', <NA>, <NA>, <NA>]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#      name   age occupation
# 0    kaif  <NA>   data eng
# 1  aaryan    27        NaN
# 2   roxoy    25        NaN
# 3     NaN    18        NaN

# %%
df.isna()
# Out:
#     name    age  occupation
# 0  False   True       False
# 1  False  False        True
# 2  False  False        True
# 3   True  False        True

# %%
df.isna().sum()
# Out:
# name          1
# age           1
# occupation    3
# dtype: int64

# %%
df.isnull()
# Out:
#     name    age  occupation
# 0  False   True       False
# 1  False  False        True
# 2  False  False        True
# 3   True  False        True

# %%
df[df.isna().any(axis = 1)]
# Out:
#      name   age occupation
# 0    kaif  <NA>   data eng
# 1  aaryan    27        NaN
# 2   roxoy    25        NaN
# 3     NaN    18        NaN

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [name, age, occupation]
# Index: []

# %%
df
# Out:
#      name   age occupation
# 0    kaif  <NA>   data eng
# 1  aaryan    27        NaN
# 2   roxoy    25        NaN
# 3     NaN    18        NaN

# %%
df.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3]

# %%
df
# Out:
#      name   age occupation
# 0    kaif  <NA>   data eng
# 1  aaryan    27        NaN
# 2   roxoy    25        NaN
# 3     NaN    18        NaN

# %%
df["name"].fillna("aaradya")
# Out:
# 0       kaif
# 1     aaryan
# 2      roxoy
# 3    aaradya
# Name: name, dtype: str

# %%
df
# Out:
#      name   age occupation
# 0    kaif  <NA>   data eng
# 1  aaryan    27        NaN
# 2   roxoy    25        NaN
# 3     NaN    18        NaN

# %%
# df.fillna(0)

# %%
# df.fillna({
#   "name":"unknown",
#   "age":"20",
#   "occupation":"unemployed"
# })

# %%
# df["age"].fillna(df["age"].median())

# %%
df
# Out:
#      name   age occupation
# 0    kaif  <NA>   data eng
# 1  aaryan    27        NaN
# 2   roxoy    25        NaN
# 3     NaN    18        NaN

# %%
df
# Out:
#      name   age occupation
# 0    kaif  <NA>   data eng
# 1  aaryan    27        NaN
# 2   roxoy    25        NaN
# 3     NaN    18        NaN

# %%
df["age"] = df["age"].bfill()
df
# Out:
#      name age occupation
# 0    kaif  27   data eng
# 1  aaryan  27        NaN
# 2   roxoy  25        NaN
# 3     NaN  18        NaN

# %%
df["occupation"] = df["occupation"].ffill()
df
# Out:
#      name age occupation
# 0    kaif  27   data eng
# 1  aaryan  27   data eng
# 2   roxoy  25   data eng
# 3     NaN  18   data eng
