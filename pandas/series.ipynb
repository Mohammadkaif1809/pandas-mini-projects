# %%
import numpy as np
import pandas as pd

# %%
#series is one dimentional

data = {
  "name":["kaif","sadhik","ishu","sonu"],
  "gender":["m","m","f","m"],
  "age":[22,14,11,19],
  "study":["grad","school","school","college"] 
}

# %%
temp = pd.Series(data)

# %%
temp
# Out:
# name           [kaif, sadhik, ishu, sonu]
# gender                       [m, m, f, m]
# age                      [22, 14, 11, 19]
# study     [grad, school, school, college]
# dtype: object

# %%
data2 = [
  ["kaif",22,"grad"],
  ["riyaz",19,"college"],
  ["munna",16,"diploma"]
]

# %%
df = pd.Series(data2)

# %%
col = ["name","age","feild"]

# %%
df.loc[2]
# Out:
# ['munna', 16, 'diploma']
